# %%
from utils import plot
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from utils.plot import _FIGURE_DIR, get_size_inches

# %%
x = np.linspace(3,5)
fig, ax = plt.subplots()
ax.plot(x,x,label=r"$c$")
ax.plot(x,17.5*(x-3)**2/((x-3)**2+1**2),label=r"$f_+(c)$")
# ax.plot(x,14*x-45.5,label=r"$g_+(c)$")
ax.plot(x,8.5*x-26.25,label=r"$g_+(c)$")
ax.axvline([3.5],color="grey",linestyle="--")
ax.axvline([4.5],color="grey",linestyle="--")
ax.set_xlabel(r"$\tilde{c}(\tilde {\boldsymbol{r}},\tilde{t})$")
ax.set_ylabel(r"RNA production/$k_p(\tilde {\boldsymbol{r}})$")
ax.legend()
# plt.savefig(_FIGURE_DIR / "SI_Hill")

# %%
(12-3.5)/(4.5-3.5)
# Out:
# 8.5

# %%
5*3.5
# Out:
# 17.5

# %%
3.5*3.5
# Out:
# 12.25

# %%
3.5-8.75*3.5
# Out:
# -27.125
