# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import plot
import seaborn as sns

# %%
df = pd.read_csv("GeneBursting.csv")

# %%
df.columns
# Out:
# Index(['proximity', 'amount'], dtype='object')

# %%
plt.scatter(df["proximity"],df["amount"])

# %%
sns.histplot(df[df["proximity"]<1]["amount"],bins=8)
# Out:
# <Axes: xlabel='amount', ylabel='Count'>

# %%
sns.histplot(df[df["proximity"]<1]["amount"],bins=10)
# Out:
# <Axes: xlabel='amount', ylabel='Count'>

# %%
sns.histplot(df[df["proximity"]<1]["amount"],bins=12)
# Out:
# <Axes: xlabel='amount', ylabel='Count'>
